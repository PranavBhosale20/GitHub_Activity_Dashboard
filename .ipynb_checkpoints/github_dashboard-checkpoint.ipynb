# %%
# github_dashboard.ipynb

import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from utils.github_api_handler import get_user_repos

# %%
pip install matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import helper functions
from utils.github_api_handler import get_user_profile, get_user_repos

# %%
# Step 2: Get and display GitHub user profile data

from utils.github_api_handler import get_user_profile

# Ask user for GitHub username
username = input("Enter GitHub username: ")

# Fetch profile data
profile_data = get_user_profile(username)

# Display key profile information
if profile_data:
    print(f"👤 Name: {profile_data.get('name')}")
    print(f"📍 Location: {profile_data.get('location')}")
    print(f"💼 Bio: {profile_data.get('bio')}")
    print(f"📊 Public Repos: {profile_data.get('public_repos')}")
    print(f"👥 Followers: {profile_data.get('followers')}")
    print(f"🔗 GitHub Profile: {profile_data.get('html_url')}")
else:
    print("❌ Could not fetch user profile.")
# Out:
# Enter GitHub username:  abhay-ugale-25
# 👤 Name: Abhay Ugale
# 📍 Location: None
# 💼 Bio: None
# 📊 Public Repos: 5
# 👥 Followers: 0
# 🔗 GitHub Profile: https://github.com/abhay-ugale-25

# %%
# Step 3: Get and display repository data

repos_data = get_user_repos(username)

# Display summary
if repos_data:
    print(f"\n📦 Total Public Repositories: {len(repos_data)}")
    print("🗃️ Repo Summary:")
    
    for repo in repos_data:
        print(f"\n🔹 Name: {repo['name']}")
        print(f"   ⭐ Stars: {repo['stargazers_count']}")
        print(f"   🍴 Forks: {repo['forks_count']}")
        print(f"   📝 Language: {repo['language']}")
        print(f"   🔗 URL: {repo['html_url']}")
else:
    print("❌ Could not fetch repositories.")
# Out:
# 📦 Total Public Repositories: 5
# 🗃️ Repo Summary:
#
# 🔹 Name: fake-news-classifier-streamlit
#    ⭐ Stars: 0
#    🍴 Forks: 0
#    📝 Language: Python
#    🔗 URL: https://github.com/abhay-ugale-25/fake-news-classifier-streamlit
#
# 🔹 Name: HR-Attrition-Analysis-Python-PowerBI
#    ⭐ Stars: 0
#    🍴 Forks: 0
#    📝 Language: Jupyter Notebook
#    🔗 URL: https://github.com/abhay-ugale-25/HR-Attrition-Analysis-Python-PowerBI
#
# 🔹 Name: Network_Traffic_Analyzer
#    ⭐ Stars: 0
#    🍴 Forks: 0
#    📝 Language: Python
#    🔗 URL: https://github.com/abhay-ugale-25/Network_Traffic_Analyzer
#
# 🔹 Name: Student-grade-flask
#    ⭐ Stars: 0
#    🍴 Forks: 0
#    📝 Language: Python
#    🔗 URL: https://github.com/abhay-ugale-25/Student-grade-flask
#
# 🔹 Name: Superstore_Sales_EDA
#    ⭐ Stars: 0
#    🍴 Forks: 0
#    📝 Language: Jupyter Notebook
#    🔗 URL: https://github.com/abhay-ugale-25/Superstore_Sales_EDA

# %%
# Step 4.1: Top 5 repositories by star count

# Sort by stars and take top 5
top_starred = sorted(repos_data, key=lambda x: x['stargazers_count'], reverse=True)[:5]

repo_names = [repo['name'] for repo in top_starred]
star_counts = [repo['stargazers_count'] for repo in top_starred]

# Plot
plt.figure(figsize=(8, 5))
sns.barplot(x=star_counts, y=repo_names, palette='viridis')
plt.title("⭐ Top 5 Repositories by Stars")
plt.xlabel("Stars")
plt.ylabel("Repository")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Baymax\AppData\Local\Temp\ipykernel_28336\667410283.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=star_counts, y=repo_names, palette='viridis')
# C:\Users\Baymax\AppData\Local\Temp\ipykernel_28336\667410283.py:15: UserWarning: Glyph 11088 (\N{WHITE MEDIUM STAR}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Baymax\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 11088 (\N{WHITE MEDIUM STAR}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Step 4.2: Languages used

from collections import Counter

languages = [repo['language'] for repo in repos_data if repo['language']]
lang_counts = Counter(languages)

# Plot
plt.figure(figsize=(6, 6))
plt.pie(lang_counts.values(), labels=lang_counts.keys(), autopct='%1.1f%%', startangle=140)
plt.title("📝 Languages Used in Public Repositories")
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Baymax\AppData\Local\Temp\ipykernel_28336\3895714396.py:13: UserWarning: Glyph 128221 (\N{MEMO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Baymax\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128221 (\N{MEMO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
